# %%
#PreProcessing
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
import joblib
import warnings
warnings.filterwarnings('ignore')
#Feature Engineering
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from xgboost import XGBClassifier        # recommended for feature importance
from catboost import CatBoostClassifier  # optional alternative, handles categorical features natively
#visualization
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import MaxNLocator
from matplotlib.colors import ListedColormap

# %%
df = pd.read_csv('D:/Machine Learning Projects/2. Employee_Attrition_Prediction/1_HR_PreProcessed.csv')

# %%
X_fe = df.drop(columns=['Attrition'])
y_fe = df['Attrition']

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_fe, y_fe)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importance = pd.DataFrame({
    'feature': X_fe.columns,
    'importance': rf.feature_importances_
}).sort_values(by='importance', ascending=False)

# %%
print(feature_importance)
# Out:
#                               feature  importance
# 11                      MonthlyIncome    0.066331
# 0                                 Age    0.051701
# 19                  TotalWorkingYears    0.049055
# 1                           DailyRate    0.047265
# 12                        MonthlyRate    0.043079
# 5                      EmployeeNumber    0.042711
# 7                          HourlyRate    0.040473
# 2                    DistanceFromHome    0.040268
# 22                     YearsAtCompany    0.035964
# 53                       OverTime_Yes    0.034714
# 52                        OverTime_No    0.032044
# 13                 NumCompaniesWorked    0.031584
# 14                  PercentSalaryHike    0.030335
# 25               YearsWithCurrManager    0.028706
# 18                   StockOptionLevel    0.028563
# 6             EnvironmentSatisfaction    0.026573
# 10                    JobSatisfaction    0.025216
# 9                            JobLevel    0.025191
# 21                    WorkLifeBalance    0.024810
# 23                 YearsInCurrentRole    0.024477
# 24            YearsSinceLastPromotion    0.021516
# 8                      JobInvolvement    0.021427
# 16           RelationshipSatisfaction    0.021282
# 20              TrainingTimesLastYear    0.021146
# 3                           Education    0.018579
# 51               MaritalStatus_Single    0.015241
# 27   BusinessTravel_Travel_Frequently    0.014672
# 31                   Department_Sales    0.009194
# 28       BusinessTravel_Travel_Rarely    0.008492
# 35             EducationField_Medical    0.008457
# 30  Department_Research & Development    0.008354
# 47            JobRole_Sales Executive    0.008200
# 39                        Gender_Male    0.008072
# 46         JobRole_Research Scientist    0.007826
# 50              MaritalStatus_Married    0.007633
# 42      JobRole_Laboratory Technician    0.007560
# 37    EducationField_Technical Degree    0.006970
# 34           EducationField_Marketing    0.006892
# 38                      Gender_Female    0.006619
# 33       EducationField_Life Sciences    0.006506
# 48       JobRole_Sales Representative    0.005506
# 49             MaritalStatus_Divorced    0.004318
# 15                  PerformanceRating    0.004133
# 41            JobRole_Human Resources    0.003489
# 26          BusinessTravel_Non-Travel    0.003408
# 44     JobRole_Manufacturing Director    0.003211
# 40  JobRole_Healthcare Representative    0.002873
# 36               EducationField_Other    0.002752
# 29         Department_Human Resources    0.002354
# 32     EducationField_Human Resources    0.002016
# 43                    JobRole_Manager    0.001704
# 45          JobRole_Research Director    0.000540
# 17                      StandardHours    0.000000
# 4                       EmployeeCount    0.000000

# %%
importance_df = pd.DataFrame({
    'Feature': X_fe.columns,
    'Importance': rf.feature_importances_
})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
threshold = 0.0045  
low_importance_features = importance_df[importance_df['Importance'] < threshold]['Feature'].tolist()
print("Dropping these columns:", low_importance_features)
# Out:
# Dropping these columns: ['MaritalStatus_Divorced', 'PerformanceRating', 'JobRole_Human Resources', 'BusinessTravel_Non-Travel', 'JobRole_Manufacturing Director', 'JobRole_Healthcare Representative', 'EducationField_Other', 'Department_Human Resources', 'EducationField_Human Resources', 'JobRole_Manager', 'JobRole_Research Director', 'StandardHours', 'EmployeeCount']

# %%
X_reduced = X_fe.drop(columns=low_importance_features)
df_final = pd.concat([X_reduced, y_fe], axis=1)

# %%
df_final.to_csv('D:/Machine Learning Projects/2. Employee_Attrition_Prediction/df_final_pre_sel.csv', index=False)
